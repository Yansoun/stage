# %%
import pandas as pd

# %%
mapper = pd.read_csv("C:\Users\yessine\ai_journey\projects\stage\app\mapping\data\processed\mappings_v2\products__TO__olist_products_dataset_mapping_suggestions_flat.csv")
# Out:
#   Cell In[7], line 1
#     mapper = pd.read_csv("C:\Users\yessine\ai_journey\projects\stage\app\mapping\data\processed\mappings_v2\products__TO__olist_products_dataset_mapping_suggestions_flat.csv")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
